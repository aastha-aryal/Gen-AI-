# %%
import tiktoken
import os
from dotenv import load_dotenv
from google import genai

load_dotenv()

client = genai.Client()

# Cell 2: Tokenization Inspection
encoding = tiktoken.get_encoding("cl100k_base")
sample_text = "Bachelor of Computer Engineering (BCT)"
tokens = encoding.encode(sample_text)
print(f"Text: {sample_text}")
print(f"Token Count: {len(tokens)}")

# Cell 3: Context-Grounded Prompt Execution
res = client.models.generate_content(
    model="gemini-3.5-flash",
    contents="Briefly define the context window in LLMs."
)
print(res.text)
# Out:
# Text: Bachelor of Computer Engineering (BCT)
# Token Count: 8
# The **context window** is the maximum amount of text (measured in tokens, which are words or parts of words) that an LLM can process in a single interaction.
#
# It acts as the model's "short-term memory," determining how much input (prompt, instructions, and past chat history) and output (the generated response) the AI can consider and "remember" at any one time. Once this limit is exceeded, the model begins to "forget" the earliest parts of the conversation.
