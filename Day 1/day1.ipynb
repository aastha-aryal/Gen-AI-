# %% [markdown]
# {
#   "cells": [
#     ...
#   ],
#   "metadata": {
#     ...
#   },
#   "nbformat": 4,
#   "nbformat_minor": 5
# }

# %%
name = "Aastha"
age = 21

print(name)
print(age)
# Out:
# Aastha
# 21
