# %%
# WRITE mode 
with open("notes.txt", "w") as file:
    file.write("Hello! This is my first text file in Python.")

print("File created successfully!")
# Out:
# File created successfully!

# %%
# READ mode
with open("notes.txt", "r") as file:
    content = file.read()

print("File Content:")
print(content)
# Out:
# File Content:
# Hello! This is my first text file in Python.

# %%
# APPEND mode
with open("notes.txt", "a") as file:
    file.write("\nThis is an additional line.")

# READ mode
with open("notes.txt", "r") as file:
    content = file.read()

print("File SUCCESSFULLY UPDATED!")
print("Updated File Content:")
print(content)
# Out:
# File SUCCESSFULLY UPDATED!
# Updated File Content:
# Hello! This is my first text file in Python.
# This is an additional line.
# This is an additional line.

# %%
import json

# Python dictionary
student = {
    "name": "Aastha",
    "age": 22,
    "skills": ["Python", "Database", "Git"]
}

# Save dictionary directly into a .json file
with open("student.json", "w") as file:
    json.dump(student, file, indent=4)  # indent=4 makes it neatly formatted!

print("JSON file saved!")
# Out:
# JSON file saved!
